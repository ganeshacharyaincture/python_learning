# %%
from pydantic import BaseModel, AnyUrl
from typing import Optional
import os

class Person(BaseModel):
    # name: Optional[str] = None
    # address: Optional[dict] = None
    website: AnyUrl


data = { "website": "tcp://google.com" }

ganesh = Person(**data)
print(os.environ["name"])
# Out:
# asdas
